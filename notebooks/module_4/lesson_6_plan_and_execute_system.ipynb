# %% [markdown]
# # Building a Plan-and-Execute Agent in LangGraph
#
# In this tutorial, we will build a plan-and-execute agent using LangGraph. This agent will:
#
# - Plan a series of steps to answer complex, multi-step queries.
# - Execute each step using tools and an LLM.
# - Re-plan if necessary, updating the plan based on intermediate results.
#
# By the end of this tutorial, you'll have a robust agent capable of handling intricate queries by planning and executing tasks systematically.

# %% [markdown]
# ### Overview
# Our agent will:
#
# 1. Receive a complex query from the user.
# 2. Plan a sequence of steps to answer the query.
# 3. Execute each step, possibly using tools (like web search).
# 4. Re-plan if needed, adjusting the plan based on new information.
# 5. Provide the final answer to the user.
#
#
# ### Imports
# We start by importing the necessary libraries:

# %%
from langchain_openai import ChatOpenAI
from langchain_community.tools import TavilySearchResults
from langgraph.graph import START, END
from langgraph.graph import StateGraph
from langgraph.checkpoint.memory import MemorySaver

from typing import Annotated, List, Tuple, Union
from typing_extensions import TypedDict

from pydantic import BaseModel, Field
from dotenv import load_dotenv
import operator

_ = load_dotenv()

# %% [markdown]
# ### Defining the Model
# We use the gpt-4o model from OpenAI:

# %%
# Defining the model
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# %% [markdown]
# ### Defining the Tools
# We will define a web search tool using Tavily:

# %%
# Tavily Search Tool
tavily_search = TavilySearchResults(max_results=3)

# List of tools for the agent
tools = [tavily_search]

# %% [markdown]
# ### Defining the State
# Our agent needs to maintain state across planning and execution steps. We define the State as follows:

# %%
class State(TypedDict):
    input: str
    plan: List[str]
    past_steps: Annotated[List[Tuple[str, str]], operator.add]  # List of (step, result)
    response: str

# %% [markdown]
# ### Planning Step
# We create a planning function that generates a plan based on the user's query:

# %%
class Plan(BaseModel):
    """Plan to follow in future"""
    steps: List[str] = Field(description="A list of steps to achieve the objective.")

from langchain_core.prompts import ChatPromptTemplate

planner_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a planning assistant that creates a simple, step-by-step plan to answer the user's query."),
        ("user", "{input}")
    ]
)

planner = planner_prompt | llm.with_structured_output(Plan)

# %% [markdown]
# ### Re-Plan Step
# If necessary, the agent can re-plan based on previous results:

# %%
class Response(BaseModel):
    """Response to the user."""
    response: str

class Act(BaseModel):
    """Action to perform."""
    action: Union[Response, Plan] = Field(description="The action to perform next.")

replanner_prompt = ChatPromptTemplate.from_template(
    """
    You are a planning assistant that updates the plan based on completed steps and their results.

    Objective: {input}
    Original Plan: {plan}
    Completed Steps: {past_steps}

    Update the plan accordingly. If all steps are complete and you can provide the final answer, respond with the answer.
    """
)

replanner = replanner_prompt | llm.with_structured_output(Act)

# %% [markdown]
# ### Defining the Execution Agent
# We shall simply use the `create_react_agent` function to create an execution agent that can perform each step using the defined tools.

# %%
from langgraph.prebuilt import create_react_agent

execution_agent = create_react_agent(llm, tools)

# %% [markdown]
# ### Creating the Graph
# We define the nodes and edges of our LangGraph:

# %%
graph_builder = StateGraph(State)

# Planning node
def planning_node(state: State):
    print("Executing planning node...")
    plan = planner.invoke({"input": state["input"]})
    print(f"Plan created: {plan.steps}")
    return {"plan": plan.steps}

graph_builder.add_node("planner", planning_node)

# Execution node
def execution_node(state: State):
    print("Executing execution node...")
    current_step = state["plan"][0]
    print(f"Current step: {current_step}")
    agent_input = f"Step: {current_step}\n\nPlease execute this step."
    agent_response = execution_agent.invoke({"messages": [("user", agent_input)]})
    result = agent_response["messages"][-1].content
    print(f"Step result: {result}")
    return {
        "past_steps": [(current_step, result)],
        "plan": state["plan"][1:]  # Remove the executed step from the plan
    }

graph_builder.add_node("executor", execution_node)

# Re-planning node
def replanning_node(state: State):
    print("Executing replanning node...")
    output = replanner.invoke(state)
    if isinstance(output.action, Response):
        print(f"Replanning complete. Final response: {output.action.response}")
        return {"response": output.action.response}
    else:
        print(f"Replanning complete. Updated plan: {output.action.steps}")
        return {"plan": output.action.steps}

graph_builder.add_node("replanner", replanning_node)

# Conditional edge to decide whether to continue or end
def should_continue(state: State):
    print("Evaluating whether to continue...")
    if state.get("response"):
        print("Final response received. Ending execution.")
        return END
    elif state["plan"]:
        print("Plan steps remaining. Continuing to executor.")
        return "executor"
    else:
        print("No plan steps remaining. Moving to replanner.")
        return "replanner"

graph_builder.add_conditional_edges(
    "replanner",
    should_continue,
    {"executor": "executor", END: END}
)

# Defining edges
graph_builder.add_edge(START, "planner")
graph_builder.add_edge("planner", "executor")
graph_builder.add_edge("executor", "replanner")
graph_builder.set_entry_point("planner")

# %% [markdown]
# ### Compiling the Graph
# We compile the graph to create a runnable agent:

# %%
# Setting up checkpointing for state management
memory = MemorySaver()

# Compiling the graph
graph = graph_builder.compile(checkpointer=memory)

# %% [markdown]
# ### Visualizing the Agent's Workflow
# We can visualize the agent's workflow:

# %%
from IPython.display import display, Image

# Visualize the agent's workflow
try:
    display(Image(graph.get_graph(xray=True).draw_mermaid_png()))
except Exception:
    pass  # Visualization requires additional dependencies

# %% [markdown]
# ### Running the Agent
# Now, we can interact with our agent.

# %%
from IPython.display import display, Markdown

user_query = "Which country will host the next FIFA World Cup, and what are the top three tourist attractions in its capital city?"
inputs = {"input": user_query}
config = {"recursion_limit": 50, "configurable": {"thread_id": "1"}}
events = graph.stream(inputs, config)
for event in events:
    for k, v in event.items():
        if k != "__end__":
            if isinstance(v, dict) and 'response' in v:
                display(Markdown(v['response']))
# Out:
# Executing planning node...
# Plan created: ['Identify the country hosting the next FIFA World Cup.', 'Research the capital city of that country.', 'List the top three tourist attractions in the capital city.']
# Executing execution node...
# Current step: Identify the country hosting the next FIFA World Cup.
# Step result: The next FIFA World Cup, scheduled for 2026, will be jointly hosted by the United States, Canada, and Mexico. The tournament will take place from June 11 to July 19, 2026. The majority of the matches will be held in the United States, with additional matches in Canada and Mexico. This will be the first World Cup to feature 48 teams, expanded from the previous 32.
#
# For more details, you can refer to the [Wikipedia page](https://en.wikipedia.org/wiki/2026_FIFA_World_Cup).
# Executing replanning node...
# Replanning complete. Updated plan: ['Research the capital city of the United States, Canada, and Mexico.', 'List the top three tourist attractions in Washington, D.C. (capital of the United States).', 'List the top three tourist attractions in Ottawa (capital of Canada).', 'List the top three tourist attractions in Mexico City (capital of Mexico).']
# Evaluating whether to continue...
# Plan steps remaining. Continuing to executor.
# Executing execution node...
# Current step: Research the capital city of the United States, Canada, and Mexico.
# Step result: Here are the capital cities of the United States, Canada, and Mexico:
#
# 1. **United States**: The capital city is **Washington, D.C.** It is located on the Potomac River and is a federal district, not part of any state. Washington, D.C. was named after George Washington, the first president of the United States. [More information](https://en.wikipedia.org/wiki/Washington,_D.C.)
#
# 2. **Canada**: The capital city is **Ottawa**. It is situated in the province of Ontario at the confluence of the Ottawa River and the Rideau River. Ottawa was incorporated in 1855 and its name comes from an Algonquin word meaning "trade." [More information](https://en.wikipedia.org/wiki/Ottawa)
#
# 3. **Mexico**: The capital city is **Mexico City** (Ciudad de México). It is the largest city in Mexico and one of the most populous cities in the world, located at a high altitude of about 2,250 meters (7,400 feet) above sea level. Mexico City has a rich history, originally serving as the center of the Aztec empire. [More information](https://www.mexperience.com/travel/big-cities/mexico-city/)
# Executing replanning node...
# Replanning complete. Updated plan: ['List the top three tourist attractions in Washington, D.C. (capital of the United States).', 'List the top three tourist attractions in Ottawa (capital of Canada).', 'List the top three tourist attractions in Mexico City (capital of Mexico).']
# Evaluating whether to continue...
# Plan steps remaining. Continuing to executor.
# Executing execution node...
# Current step: List the top three tourist attractions in Washington, D.C. (capital of the United States).
# Step result: The top three tourist attractions in Washington, D.C. are:
#
# 1. **The National Mall**: This iconic stretch of land is home to many of the nation's most famous monuments and memorials, including the Lincoln Memorial and the Washington Monument. It serves as a central hub for visitors to explore the history and culture of the United States. The National Mall is also a great place for walking, relaxing, and enjoying the open green space.
#
# 2. **The Smithsonian Institution**: Comprising multiple museums, the Smithsonian is renowned for its vast collection of art, history, and science exhibits. Key museums include the National Air and Space Museum, the National Museum of Natural History, and the National Museum of American History. Admission to these museums is free, making them a must-visit for anyone in D.C.
#
# 3. **The White House**: As the official residence and workplace of the President of the United States, the White House is an iconic symbol of American government. Visitors can take guided tours to learn about its history and significance.
#
# For more information, you can check out the following resources:
# - [Tripadvisor - Top Attractions in Washington DC](https://www.tripadvisor.com/Attractions-g28970-Activities-Washington_DC_District_of_Columbia.html)
# - [Travel US News - Things To Do in Washington DC](https://travel.usnews.com/Washington_DC/Things_To_Do/)
# Executing replanning node...
# Replanning complete. Updated plan: ['List the top three tourist attractions in Ottawa (capital of Canada).', 'List the top three tourist attractions in Mexico City (capital of Mexico).']
# Evaluating whether to continue...
# Plan steps remaining. Continuing to executor.
# Executing execution node...
# Current step: List the top three tourist attractions in Ottawa (capital of Canada).
# Step result: The top three tourist attractions in Ottawa, Canada, are:
#
# 1. **Parliament Hill** - This iconic site is the heart of Canada's government and features stunning Gothic Revival architecture. Visitors can explore the grounds, attend the Changing of the Guard ceremony, and enjoy guided tours of the buildings.
#
# 2. **National Gallery of Canada** - This art museum houses an impressive collection of Canadian and international art, including works by renowned artists. The building itself is a masterpiece, featuring a glass and granite design.
#
# 3. **Canadian Museum of History** - Located across the river in Gatineau, this museum offers insights into Canada's past, showcasing exhibits on the country's history, culture, and indigenous peoples. The architecture of the museum is also noteworthy.
#
# For more information, you can visit the following links:
# - [Wikipedia - List of tourist attractions in Ottawa](https://en.wikipedia.org/wiki/List_of_tourist_attractions_in_Ottawa)
# - [Tripadvisor - Attractions in Ottawa](https://www.tripadvisor.com/Attractions-g155004-Activities-Ottawa_Ontario.html)
# Executing replanning node...
# Replanning complete. Updated plan: ['List the top three tourist attractions in Mexico City (capital of Mexico).']
# Evaluating whether to continue...
# Plan steps remaining. Continuing to executor.
# Executing execution node...
# Current step: List the top three tourist attractions in Mexico City (capital of Mexico).
# Step result: Here are the top three tourist attractions in Mexico City:
#
# 1. **Zócalo (Plaza de la Constitución)**: This historic square is the heart of Mexico City and is surrounded by significant landmarks, including the National Palace, the Metropolitan Cathedral, and the Templo Mayor, which features Aztec relics. It's a vibrant area used for festivals, parades, and demonstrations.
#
# 2. **Frida Kahlo Museum (La Casa Azul)**: Located in the Coyoacán neighborhood, this museum is dedicated to the life and work of the famous Mexican artist Frida Kahlo. It showcases her paintings, personal items, and works by her husband, Diego Rivera. It's advisable to purchase tickets in advance due to its popularity.
#
# 3. **El Ángel de la Independencia**: This iconic monument, also known as the Monumento a la Independencia, is located on Avenida Paseo de la Reforma. It is a significant symbol of Mexico's independence and is a popular spot for both locals and tourists.
#
# For more details, you can check the sources: [PlanetWare](https://www.planetware.com/tourist-attractions-/mexico-city-mex-df-mexc.htm) and [Eternal Spring](https://www.eternalspringcdmx.com/p/mexico-citys-15-top-must-see-attractions-for-visitors-and-tourists).
# Executing replanning node...
# Replanning complete. Updated plan: ['Identify the country hosting the next FIFA World Cup.', 'Research the capital city of the United States, Canada, and Mexico.', 'List the top three tourist attractions in Washington, D.C. (capital of the United States).', 'List the top three tourist attractions in Ottawa (capital of Canada).', 'List the top three tourist attractions in Mexico City (capital of Mexico).']
# Evaluating whether to continue...
# Plan steps remaining. Continuing to executor.
# Executing execution node...
# Current step: Identify the country hosting the next FIFA World Cup.
# Step result: The next FIFA World Cup, scheduled for 2026, will be jointly hosted by the United States, Canada, and Mexico. The tournament will take place from June 11 to July 19, 2026, and will feature matches in 16 cities across these three countries. This event will mark the first time that three countries have jointly hosted a World Cup.
# Executing replanning node...
# Replanning complete. Final response: The next FIFA World Cup will be jointly hosted by the **United States**, **Canada**, and **Mexico** in 2026. The capital cities and their top three tourist attractions are as follows:
#
# 1. **Washington, D.C. (United States)**:
#    - **The National Mall**: Home to many famous monuments and memorials.
#    - **The Smithsonian Institution**: A collection of museums with free admission.
#    - **The White House**: The official residence of the President of the United States.
#
# 2. **Ottawa (Canada)**:
#    - **Parliament Hill**: The heart of Canada's government with stunning architecture.
#    - **National Gallery of Canada**: An art museum with a vast collection.
#    - **Canadian Museum of History**: Showcasing Canada's past and culture.
#
# 3. **Mexico City (Mexico)**:
#    - **Zócalo (Plaza de la Constitución)**: A historic square surrounded by significant landmarks.
#    - **Frida Kahlo Museum (La Casa Azul)**: Dedicated to the life of the artist Frida Kahlo.
#    - **El Ángel de la Independencia**: An iconic monument symbolizing Mexico's independence.
#
# This information provides a comprehensive overview of the next FIFA World Cup and the top tourist attractions in the capital cities of the host countries.
# Evaluating whether to continue...
# Final response received. Ending execution.
# The next FIFA World Cup will be jointly hosted by the **United States**, **Canada**, and **Mexico** in 2026. The capital cities and their top three tourist attractions are as follows:
#
# 1. **Washington, D.C. (United States)**:
#    - **The National Mall**: Home to many famous monuments and memorials.
#    - **The Smithsonian Institution**: A collection of museums with free admission.
#    - **The White House**: The official residence of the President of the United States.
#
# 2. **Ottawa (Canada)**:
#    - **Parliament Hill**: The heart of Canada's government with stunning architecture.
#    - **National Gallery of Canada**: An art museum with a vast collection.
#    - **Canadian Museum of History**: Showcasing Canada's past and culture.
#
# 3. **Mexico City (Mexico)**:
#    - **Zócalo (Plaza de la Constitución)**: A historic square surrounded by significant landmarks.
#    - **Frida Kahlo Museum (La Casa Azul)**: Dedicated to the life of the artist Frida Kahlo.
#    - **El Ángel de la Independencia**: An iconic monument symbolizing Mexico's independence.
#
# This information provides a comprehensive overview of the next FIFA World Cup and the top tourist attractions in the capital cities of the host countries.

# %% [markdown]
# ### Conclusion
# Congratulations! You've built a plan-and-execute agent using LangGraph that can handle complex, multi-step queries by planning and executing tasks systematically.
#
# Feel free to experiment further by:
#
# - Adding more tools.
# - Modifying the planning and replanning prompts.
# - Handling different types of multi-step queries.
